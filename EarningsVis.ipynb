# %% [markdown]
# # Guided Project: Visualizing Earnings Based On College Majors

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# #### Description of the data set

# %% [markdown]
# **Rank** - Rank by median earnings (the dataset is ordered by this column).<br>
# **Major_code** - Major code.<br>
# **Major** - Major description.<br>
# **Major_category** - Category of major.<br>
# **Total** - Total number of people with major.<br>
# **Sample_size** - Sample size (unweighted) of full-time.<br>
# **Men** - Male graduates.<br>
# **Women** - Female graduates.<br>
# **ShareWomen** - Women as share of total.<br>
# **Employed** - Number employed.<br>
# **Median** - Median salary of full-time, year-round workers.<br>
# **Low_wage_jobs** - Number in low-wage service jobs.<br>
# **Full_time** - Number employed 35 hours or more.<br>
# **Part_time** - Number employed less than 35 hours.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

recent_grads = pd.read_csv('recent-grads.csv')
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head(2)
# Out:
#    Rank  Major_code                           Major   Total     Men  Women  \
# 0     1        2419           PETROLEUM ENGINEERING  2339.0  2057.0  282.0
# 1     2        2416  MINING AND MINERAL ENGINEERING   756.0   679.0   77.0
#
#   Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  \
# 0    Engineering    0.120564           36      1976      ...              270
# 1    Engineering    0.101852            7       640      ...              170
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
# 1                   388          85           0.117241   75000  55000   90000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 0          1534               364            193
# 1           350               257             50
#
# [2 rows x 21 columns]

# %%
recent_grads.tail(2)
# Out:
#      Rank  Major_code                  Major   Total    Men   Women  \
# 171   172        5203  COUNSELING PSYCHOLOGY  4626.0  931.0  3695.0
# 172   173        3501        LIBRARY SCIENCE  1098.0  134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 171      ...              965                  2738         214
# 172      ...              237                   410          87
#
#      Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  \
# 171           0.053621   23400  19200  26000          2403              1245
# 172           0.104946   22000  20000  22000           288               338
#
#      Low_wage_jobs
# 171            308
# 172            192
#
# [2 rows x 21 columns]

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
cnt = recent_grads.count()

# %%
cnt
# Out:
# Rank                    173
# Major_code              173
# Major                   173
# Total                   172
# Men                     172
# Women                   172
# Major_category          173
# ShareWomen              172
# Sample_size             173
# Employed                173
# Full_time               173
# Part_time               173
# Full_time_year_round    173
# Unemployed              173
# Unemployment_rate       173
# Median                  173
# P25th                   173
# P75th                   173
# College_jobs            173
# Non_college_jobs        173
# Low_wage_jobs           173
# dtype: int64

# %%
raw_data_count = cnt['Rank']
raw_data_count
# Out:
# 173

# %%
recent_grads = recent_grads.dropna()

# %%
cleaned_data_count = recent_grads.count()["Rank"]
cleaned_data_count
# Out:
# 172

# %% [markdown]
# ## 2. Pandas, Scatter Plots

# %%
recent_grads.plot(x='Sample_size', y='Median',
                  kind='scatter', title='Sample_size vs. Median',
                  figsize=(5,5))

# %% [markdown]
# >If sample size is any indication of major popularity then it looks like popular majors don't necessarily mean higher salaries.

# %%
recent_grads.plot(x = 'Sample_size', 
                  y = 'Unemployment_rate',
                 kind  = 'scatter',
                 title = 'Sample Size vs. Unemployment Rate')

# %%
recent_grads.plot(x = 'Full_time',
                 y = 'Median',
                 kind = 'scatter',
                 title = 'Full Time vs. Median')

# %%
recent_grads.plot(x = 'ShareWomen',
                 y = 'Unemployment_rate',
                 kind = 'scatter',
                 title = 'Share of Women vs. Unemployment Rate')

# %%
recent_grads.plot(x= 'Men',
                 y = 'Median',
                 kind = 'scatter',
                 title = 'Men vs. Median')

# %%
recent_grads.plot(x = 'Women',
                 y = 'Median',
                 kind = 'scatter',
                 title = 'Women vs. Median')

# %%
recent_grads.plot(x = 'ShareWomen',
                  y = 'Median',
                  kind = 'scatter',
                  title = 'Share of Women vs. Median Income')

# %% [markdown]
# >Majority female dominated subjects lead to jobs, paying lower median salaries.
# As far as unqmployment rate is concerned - no pattern is discernible.

# %% [markdown]
# >The number of full tyme employed students per major doesn't affect the level of salary.

# %% [markdown]
# ## 3. Pandas, Histograms

# %%
ax1 = recent_grads['Sample_size'].hist(bins=50, range=(0,5000))
ax1.set_title('Sizes of the Major Samples')

# %%
ax2 = recent_grads['Median'].hist(bins = 50, range = (0,120000))
ax2.set_title('Median Salaries For Recent Graduates')

# %%
ax3 = recent_grads['Employed'].hist(bins = 50, range = (0,310000))
ax3.set_title('Number of Employed Graduates')

# %%
ax4 = recent_grads['Full_time'].hist(bins = 50, range = (0,260000))
ax4.set_title('Full Time Empoyed Grads')

# %%
ax5 = recent_grads['ShareWomen'].hist(bins = 50, range = (0,1))
ax5.set_title('Share of Women')

# %%
ax6 = recent_grads['Unemployment_rate'].hist(bins = 50, range = (0,.2))
ax6.set_title('Unemployment Rate')

# %%
ax7 = recent_grads['Men'].hist(bins = 50, range = (0,200000))
ax7.set_title('Men Graduates')

# %%
ax7 = recent_grads['Women'].hist(bins = 50, range = (0,200000))
ax7.set_title('Women Graduates')

# %% [markdown]
# ## 4. Pandas, Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe5f517b0b8>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize = (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe5f76ec588>,
# ...
#       dtype=object)

# %% [markdown]
# ## 5. Pandas, Bar Plots

# %%
recent_grads.head().plot.bar(y = 'ShareWomen', x = 'Major')

# %%
recent_grads.tail().plot.bar(y = 'ShareWomen', x = 'Major')

# %%
recent_grads.head().plot.bar(y='Unemployment_rate', x = 'Major')

# %%
recent_grads.tail().plot.bar(y='Unemployment_rate', x = 'Major')

# %% [markdown]
# ## 6. Next Steps

# %% [markdown]
# #### Women vs Men

# %%
d=pd.pivot_table(recent_grads[['Major_category', 'Men', 'Women']], 
                 values = ['Men', 'Women'], 
                 index = 'Major_category')
ax1 = d.plot.bar()
ax1.set_title('Women vs Men for each Major')

# %% [markdown]
# #### Distributions of Median Salaries and Unempoyment rates

# %%
ax_1 = recent_grads.boxplot(column = ['Median'],
                         by=['Major_category'], rot = 90)

# %%
recent_grads.boxplot(column = ['Unemployment_rate'], 
                      by = ['Major_category'],
                    rot = 90)

# %% [markdown]
# #### Hexagonal bin plots for the scatterplots from the beginning of the project

# %%
recent_grads.plot(x='Sample_size', y='Median',
                  kind='hexbin', title='Sample_size vs. Median',
                  figsize=(5,5))

# %%
recent_grads.plot(x = 'Sample_size', 
                  y = 'Unemployment_rate',
                 kind  = 'hexbin',
                 title = 'Sample Size vs. Unemployment Rate')

# %%
recent_grads.plot(x = 'Full_time',
                 y = 'Median',
                 kind = 'hexbin',
                 title = 'Full Time vs. Median')
